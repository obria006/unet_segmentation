# %% [markdown]
# # Train U-Net Segmentation
# This can be run in Jupyter notebook on local computer to train the network. Adapted from DL4MIA 2022 Unet.
# https://github.com/dl4mia

# %% [markdown]
# ## Display network training hardware
# This will display whether the training device is GPU (cuda) or CPU. GPU will train the network substantially faster than CPU.

# %%
# setting device on GPU if available, else CPU
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce RTX 2080 SUPER
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# ## Start training
#
# At a minimum, you must specify the:
# 1. Data directory (`data_dir`) which is the directory where the "train", "test", and "val" folders are located that contain processed images/masks.
# 2. Output/results directory (`output_dir`) which is the directory where the training results will be saved. Within this directory, folders for each training session will be created.
#
# Addtionally, you can view the `main()` function parameters in the "train.py" file to see other keyword arguments that can be specified. For instance, you can change the number of training epochs, number of layers in the U-Net, and the size to which input images will be resized prior to training.

# %%
from src.models.dl4mia_tissue_unet import train
data_dir = "../data/processed/OCT_scans_128x128"
output_dir = "../src/models/dl4mia_tissue_unet/results"
n_epochs = 30
in_size = (128, 128)
n_levels = 3
train.main(data_dir=data_dir, output_dir = output_dir, n_epochs=n_epochs, in_size=in_size, n_levels=n_levels)
# Out:
# Training dictionary:
# kwargs:
#   data_dir: ../data/processed/OCT_scans_128x128
#   data_type: train
#   size: 54
#   transform:
#     NumpyToTensor:
#       img_dtype: float
#       mask_dtype: short
#     RandomRotationTransform:
#       angles:
#       - 0
#       - 90
#       - 180
#     RandomFlip: {}
#     ResizeTransform:
#       size: !!python/tuple
#       - 128
#       - 128
# batch_size: 8
# workers: 12
#
#
# Validation dictionary:
# kwargs:
#   data_dir: ../data/processed/OCT_scans_128x128
#   data_type: val
#   size: 15
#   transform:
#     NumpyToTensor:
#       img_dtype: float
#       mask_dtype: short
#     RandomRotationTransform:
#       angles:
#       - 0
#       - 90
#       - 180
#     RandomFlip: {}
#     ResizeTransform:
#       size: !!python/tuple
#       - 128
#       - 128
# batch_size: 8
# workers: 12
#
#
# Test dictionary:
# kwargs:
#   data_dir: ../data/processed/OCT_scans_128x128
#   data_type: test
#   size: 8
#   transform: null
# batch_size: 8
# workers: 12
#
#
# Model dictionary:
# name: unet
# kwargs:
#   num_classes: 1
#   depth: 3
#   in_channels: 1
#
#
# Config dictionary:
# train_lr: 0.0005
# n_epochs: 30
# cuda: true
# save: true
# save_dir: ../src/models/dl4mia_tissue_unet/results/20230421_171049
# resume_path: null
#
#
# loading datasets...
# 2D `train` Dataset created.
# 2D `val` Dataset created.
#
# creating model...
# Created logger with keys:  ('train', 'val', 'ap')
# Starting epoch 0
# learning rate: 0.0005
# 100%|██████████| 6/6 [00:09<00:00,  1.55s/it]
# 100%|██████████| 1/1 [00:04<00:00,  4.12s/it]
# ===> train loss: 0.38
# ===> val loss: 0.52, val ap: 0.00
# => saving checkpoint
# Starting epoch 1
# learning rate: 0.0004977494364660346
# 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.14s/it]
# ===> train loss: 0.19
# ===> val loss: 0.34, val ap: 0.00
# => saving checkpoint
# Starting epoch 2
# learning rate: 0.0004954977417064171
# 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.15s/it]
# ===> train loss: 0.14
# ===> val loss: 0.26, val ap: 0.00
# => saving checkpoint
# Starting epoch 3
# learning rate: 0.0004932449094349202
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.24s/it]
# ===> train loss: 0.12
# ===> val loss: 0.20, val ap: 0.00
# => saving checkpoint
# Starting epoch 4
# learning rate: 0.0004909909332982877
# 100%|██████████| 6/6 [00:04<00:00,  1.44it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.17s/it]
# ===> train loss: 0.11
# ===> val loss: 0.18, val ap: 0.00
# => saving checkpoint
# Starting epoch 5
# learning rate: 0.0004887358068751748
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# ===> train loss: 0.10
# ===> val loss: 0.18, val ap: 0.00
# => saving checkpoint
# Starting epoch 6
# learning rate: 0.0004864795236750653
# 100%|██████████| 6/6 [00:04<00:00,  1.39it/s]
# 100%|██████████| 1/1 [00:07<00:00,  7.10s/it]
# ===> train loss: 0.09
# ===> val loss: 0.19, val ap: 0.00
# => saving checkpoint
# Starting epoch 7
# learning rate: 0.00048422207713716544
# 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.17s/it]
# ===> train loss: 0.09
# ===> val loss: 0.17, val ap: 0.00
# => saving checkpoint
# Starting epoch 8
# learning rate: 0.00048196346062927547
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]
# ===> train loss: 0.08
# ===> val loss: 0.16, val ap: 0.01
# => saving checkpoint
# Starting epoch 9
# learning rate: 0.00047970366744663594
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.19s/it]
# ===> train loss: 0.08
# ===> val loss: 0.11, val ap: 0.17
# => saving checkpoint
# Starting epoch 10
# learning rate: 0.00047744269081074987
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.21s/it]
# ===> train loss: 0.07
# ===> val loss: 0.09, val ap: 0.66
# => saving checkpoint
# Starting epoch 11
# learning rate: 0.0004751805238681794
# 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.17s/it]
# ===> train loss: 0.07
# ===> val loss: 0.08, val ap: 0.78
# => saving checkpoint
# Starting epoch 12
# learning rate: 0.000472917159689316
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.17s/it]
# ===> train loss: 0.07
# ===> val loss: 0.07, val ap: 0.80
# => saving checkpoint
# Starting epoch 13
# learning rate: 0.00047065259126712457
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.21s/it]
# ===> train loss: 0.07
# ===> val loss: 0.07, val ap: 0.83
# => saving checkpoint
# Starting epoch 14
# learning rate: 0.00046838681151585874
# 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.26s/it]
# ===> train loss: 0.07
# ===> val loss: 0.07, val ap: 0.83
# => saving checkpoint
# Starting epoch 15
# learning rate: 0.0004661198132697498
# 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# ===> train loss: 0.06
# ===> val loss: 0.06, val ap: 0.85
# => saving checkpoint
# Starting epoch 16
# learning rate: 0.0004638515892816641
# 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# ===> train loss: 0.06
# ===> val loss: 0.07, val ap: 0.86
# => saving checkpoint
# Starting epoch 17
# learning rate: 0.00046158213222173284
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# ===> train loss: 0.06
# ===> val loss: 0.06, val ap: 0.84
# => saving checkpoint
# Starting epoch 18
# learning rate: 0.0004593114346759497
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.45s/it]
# ===> train loss: 0.06
# ===> val loss: 0.06, val ap: 0.86
# => saving checkpoint
# Starting epoch 19
# learning rate: 0.00045703948914473726
# 100%|██████████| 6/6 [00:04<00:00,  1.37it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.29s/it]
# ===> train loss: 0.06
# ===> val loss: 0.06, val ap: 0.85
# => saving checkpoint
# Starting epoch 20
# learning rate: 0.00045476628804148113
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.35s/it]
# ===> train loss: 0.06
# ===> val loss: 0.05, val ap: 0.86
# => saving checkpoint
# Starting epoch 21
# learning rate: 0.00045249182369103055
# 100%|██████████| 6/6 [00:04<00:00,  1.37it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# ===> train loss: 0.05
# ===> val loss: 0.06, val ap: 0.85
# => saving checkpoint
# Starting epoch 22
# learning rate: 0.00045021608832816447
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.14s/it]
# ===> train loss: 0.06
# ===> val loss: 0.05, val ap: 0.86
# => saving checkpoint
# Starting epoch 23
# learning rate: 0.0004479390740960227
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.24s/it]
# ===> train loss: 0.05
# ===> val loss: 0.06, val ap: 0.84
# => saving checkpoint
# Starting epoch 24
# learning rate: 0.00044566077304449995
# 100%|██████████| 6/6 [00:04<00:00,  1.43it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.24s/it]
# ===> train loss: 0.06
# ===> val loss: 0.06, val ap: 0.83
# => saving checkpoint
# Starting epoch 25
# learning rate: 0.00044338117712860363
# 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.33s/it]
# ===> train loss: 0.05
# ===> val loss: 0.05, val ap: 0.86
# => saving checkpoint
# Starting epoch 26
# learning rate: 0.00044110027820677195
# 100%|██████████| 6/6 [00:04<00:00,  1.44it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.20s/it]
# ===> train loss: 0.05
# ===> val loss: 0.06, val ap: 0.84
# => saving checkpoint
# Starting epoch 27
# learning rate: 0.000438818068039153
# 100%|██████████| 6/6 [00:04<00:00,  1.44it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.18s/it]
# ===> train loss: 0.05
# ===> val loss: 0.05, val ap: 0.87
# => saving checkpoint
# Starting epoch 28
# learning rate: 0.000436534538285843
# 100%|██████████| 6/6 [00:04<00:00,  1.43it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.26s/it]
# ===> train loss: 0.05
# ===> val loss: 0.05, val ap: 0.84
# => saving checkpoint
# Starting epoch 29
# learning rate: 0.00043424968050508256
# 100%|██████████| 6/6 [00:04<00:00,  1.42it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.30s/it]
# ===> train loss: 0.05
# ===> val loss: 0.05, val ap: 0.82
# => saving checkpoint

# %% [markdown]
# ## Predictions

# %%
# %load_ext autoreload
# %autoreload 2
from src.models.dl4mia_tissue_unet import predict
import glob
res_dirs = glob.glob(f"{output_dir}/*")
if res_dirs != []:
  result_dir = res_dirs[-1]
  ckpt_name = "best.pth"
  deploy_dir = "../data/OCT_scans/raw/images"
  predict.main(src_dir=result_dir, ckpt_name=ckpt_name, deploy_dir=None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [INFO] loading up test image paths...
# Loading model...
# Loaded checkpoint: ../src/models/dl4mia_tissue_unet/results\20230421_171049/best.pth
# 	epoch = 27
# 	val_loss = 0.051513440907001495
# 	val_ap = 0.8676014477648781
# 	best_ap = 0.8676014477648781
# 	train_cuda = True
# 	model_dict = {'name': 'unet', 'kwargs': {'num_classes': 1, 'depth': 3, 'in_channels': 1}}
# Load time: 0.27906322479248047
# Predict time: 0.055013179779052734
# c:\virenvs\oct_segmentation\unet_segmentation\src\models\dl4mia_tissue_unet\predict.py:185: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()
# Predict time: 0.06101393699645996
# Predict time: 0.09402108192443848
# Predict time: 0.02100539207458496
# Predict time: 0.02500605583190918
