# %% [markdown]
# # Train U-Net Segmentation
# This can be run in Jupyter notebook on local computer to train the network. Adapted from DL4MIA 2022 Unet.
# https://github.com/dl4mia

# %% [markdown]
# ## Display network training hardware
# This will display whether the training device is GPU (cuda) or CPU. GPU will train the network substantially faster than CPU.

# %%
# setting device on GPU if available, else CPU
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
#
# NVIDIA GeForce RTX 2080 SUPER
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    1.5 GB

# %% [markdown]
# ## Start training
#
# At a minimum, you must specify the:
# 1. Data directory (`data_dir`) which is the directory where the "train", "test", and "val" folders are located that contain processed images/masks.
# 2. Output/results directory (`output_dir`) which is the directory where the training results will be saved. Within this directory, folders for each training session will be created.
#
# Addtionally, you can view the `main()` function parameters in the "train.py" file to see other keyword arguments that can be specified. For instance, you can change the number of training epochs, number of layers in the U-Net, and the size to which input images will be resized prior to training.

# %%
from src.models.dl4mia_tissue_unet import train
data_dir = "../data/processed/OCT_scans_128x128"
output_dir = "../src/models/dl4mia_tissue_unet/results"
n_epochs = 30
in_size = (128, 128)
n_levels = 3
train.main(data_dir=data_dir, output_dir = output_dir, n_epochs=n_epochs, in_size=in_size, n_levels=n_levels)
# Out:
# Training dictionary:
# kwargs:
#   data_dir: ../data/processed/OCT_scans_128x128
#   data_type: train
#   size: 54
#   transform:
#     NumpyToTensor:
#       img_dtype: float
#       mask_dtype: short
#     RandomRotationTransform:
#       angles:
#       - 0
#       - 90
#       - 180
#     RandomFlip: {}
#     ResizeTransform:
#       size: !!python/tuple
#       - 128
#       - 128
# batch_size: 8
# workers: 12
#
#
# Validation dictionary:
# kwargs:
#   data_dir: ../data/processed/OCT_scans_128x128
#   data_type: val
#   size: 15
#   transform:
#     NumpyToTensor:
#       img_dtype: float
#       mask_dtype: short
#     RandomRotationTransform:
#       angles:
#       - 0
#       - 90
#       - 180
#     RandomFlip: {}
#     ResizeTransform:
#       size: !!python/tuple
#       - 128
#       - 128
# batch_size: 8
# workers: 12
#
#
# Test dictionary:
# kwargs:
#   data_dir: ../data/processed/OCT_scans_128x128
#   data_type: test
#   size: 8
#   transform: null
# batch_size: 8
# workers: 12
#
#
# Model dictionary:
# name: unet
# kwargs:
#   num_classes: 1
#   depth: 3
#   in_channels: 1
#   batch_norm: true
#
#
# Config dictionary:
# train_lr: 0.001
# n_epochs: 30
# cuda: true
# save: true
# save_dir: ../src/models/dl4mia_tissue_unet/results/20230424_120831
# resume_path: null
#
#
# loading datasets...
# 2D `train` Dataset created.
# 2D `val` Dataset created.
#
# creating model...
# Created logger with keys:  ('train', 'val', 'ap', 'dice')
# Starting epoch 0
# learning rate: 0.001
# 100%|██████████| 6/6 [00:07<00:00,  1.17s/it]
# 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]
# ===> train loss:	0.75
# ===> val loss:		0.92
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 1
# learning rate: 0.0009954988729320691
# 100%|██████████| 6/6 [00:04<00:00,  1.49it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.06s/it]
# ===> train loss:	0.62
# ===> val loss:		0.91
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 2
# learning rate: 0.0009909954834128342
# 100%|██████████| 6/6 [00:04<00:00,  1.43it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.47s/it]
# ===> train loss:	0.58
# ===> val loss:		0.88
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 3
# learning rate: 0.0009864898188698403
# 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.21s/it]
# ===> train loss:	0.54
# ===> val loss:		0.88
# ===> val ap:		0.37
# ===> val dice:		0.52
# => saving checkpoint
# Starting epoch 4
# learning rate: 0.0009819818665965754
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.24s/it]
# ===> train loss:	0.51
# ===> val loss:		0.91
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 5
# learning rate: 0.0009774716137503495
# 100%|██████████| 6/6 [00:04<00:00,  1.50it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
# ===> train loss:	0.48
# ===> val loss:		0.92
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 6
# learning rate: 0.0009729590473501306
# 100%|██████████| 6/6 [00:04<00:00,  1.44it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.23s/it]
# ===> train loss:	0.45
# ===> val loss:		0.92
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 7
# learning rate: 0.0009684441542743309
# 100%|██████████| 6/6 [00:04<00:00,  1.49it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.19s/it]
# ===> train loss:	0.43
# ===> val loss:		0.93
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 8
# learning rate: 0.0009639269212585509
# 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.36s/it]
# ===> train loss:	0.42
# ===> val loss:		0.93
# ===> val ap:		1.00
# ===> val dice:		0.00
# => saving checkpoint
# Starting epoch 9
# learning rate: 0.0009594073348932719
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.34s/it]
# ===> train loss:	0.39
# ===> val loss:		0.76
# ===> val ap:		0.92
# ===> val dice:		0.30
# => saving checkpoint
# Starting epoch 10
# learning rate: 0.0009548853816214997
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.10s/it]
# ===> train loss:	0.35
# ===> val loss:		0.51
# ===> val ap:		0.90
# ===> val dice:		0.70
# => saving checkpoint
# Starting epoch 11
# learning rate: 0.0009503610477363587
# 100%|██████████| 6/6 [00:03<00:00,  1.53it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.21s/it]
# ===> train loss:	0.33
# ===> val loss:		0.39
# ===> val ap:		0.86
# ===> val dice:		0.81
# => saving checkpoint
# Starting epoch 12
# learning rate: 0.000945834319378632
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# ===> train loss:	0.31
# ===> val loss:		0.41
# ===> val ap:		0.87
# ===> val dice:		0.75
# => saving checkpoint
# Starting epoch 13
# learning rate: 0.0009413051825342491
# 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# ===> train loss:	0.29
# ===> val loss:		0.34
# ===> val ap:		0.88
# ===> val dice:		0.83
# => saving checkpoint
# Starting epoch 14
# learning rate: 0.0009367736230317175
# 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.12s/it]
# ===> train loss:	0.29
# ===> val loss:		0.29
# ===> val ap:		0.79
# ===> val dice:		0.83
# => saving checkpoint
# Starting epoch 15
# learning rate: 0.0009322396265394996
# 100%|██████████| 6/6 [00:04<00:00,  1.50it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# ===> train loss:	0.27
# ===> val loss:		0.27
# ===> val ap:		0.80
# ===> val dice:		0.84
# => saving checkpoint
# Starting epoch 16
# learning rate: 0.0009277031785633282
# 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.19s/it]
# ===> train loss:	0.26
# ===> val loss:		0.26
# ===> val ap:		0.81
# ===> val dice:		0.85
# => saving checkpoint
# Starting epoch 17
# learning rate: 0.0009231642644434657
# 100%|██████████| 6/6 [00:04<00:00,  1.49it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.22s/it]
# ===> train loss:	0.25
# ===> val loss:		0.29
# ===> val ap:		0.72
# ===> val dice:		0.80
# => saving checkpoint
# Starting epoch 18
# learning rate: 0.0009186228693518994
# 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.19s/it]
# ===> train loss:	0.25
# ===> val loss:		0.23
# ===> val ap:		0.87
# ===> val dice:		0.86
# => saving checkpoint
# Starting epoch 19
# learning rate: 0.0009140789782894745
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.08s/it]
# ===> train loss:	0.24
# ===> val loss:		0.21
# ===> val ap:		0.86
# ===> val dice:		0.86
# => saving checkpoint
# Starting epoch 20
# learning rate: 0.0009095325760829623
# 100%|██████████| 6/6 [00:04<00:00,  1.43it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# ===> train loss:	0.22
# ===> val loss:		0.23
# ===> val ap:		0.76
# ===> val dice:		0.83
# => saving checkpoint
# Starting epoch 21
# learning rate: 0.0009049836473820611
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.15s/it]
# ===> train loss:	0.22
# ===> val loss:		0.24
# ===> val ap:		0.74
# ===> val dice:		0.83
# => saving checkpoint
# Starting epoch 22
# learning rate: 0.0009004321766563289
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.34s/it]
# ===> train loss:	0.22
# ===> val loss:		0.24
# ===> val ap:		0.74
# ===> val dice:		0.82
# => saving checkpoint
# Starting epoch 23
# learning rate: 0.0008958781481920453
# 100%|██████████| 6/6 [00:04<00:00,  1.45it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.26s/it]
# ===> train loss:	0.21
# ===> val loss:		0.26
# ===> val ap:		0.90
# ===> val dice:		0.82
# => saving checkpoint
# Starting epoch 24
# learning rate: 0.0008913215460889999
# 100%|██████████| 6/6 [00:04<00:00,  1.49it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.40s/it]
# ===> train loss:	0.20
# ===> val loss:		0.22
# ===> val ap:		0.85
# ===> val dice:		0.84
# => saving checkpoint
# Starting epoch 25
# learning rate: 0.0008867623542572073
# 100%|██████████| 6/6 [00:04<00:00,  1.48it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.08s/it]
# ===> train loss:	0.19
# ===> val loss:		0.18
# ===> val ap:		0.81
# ===> val dice:		0.86
# => saving checkpoint
# Starting epoch 26
# learning rate: 0.0008822005564135439
# 100%|██████████| 6/6 [00:04<00:00,  1.47it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# ===> train loss:	0.19
# ===> val loss:		0.25
# ===> val ap:		0.69
# ===> val dice:		0.80
# => saving checkpoint
# Starting epoch 27
# learning rate: 0.000877636136078306
# 100%|██████████| 6/6 [00:04<00:00,  1.46it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.21s/it]
# ===> train loss:	0.20
# ===> val loss:		0.26
# ===> val ap:		0.65
# ===> val dice:		0.78
# => saving checkpoint
# Starting epoch 28
# learning rate: 0.000873069076571686
# 100%|██████████| 6/6 [00:03<00:00,  1.51it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.11s/it]
# ===> train loss:	0.18
# ===> val loss:		0.17
# ===> val ap:		0.86
# ===> val dice:		0.88
# => saving checkpoint
# Starting epoch 29
# learning rate: 0.0008684993610101651
# 100%|██████████| 6/6 [00:04<00:00,  1.50it/s]
# 100%|██████████| 1/1 [00:04<00:00,  4.19s/it]
# ===> train loss:	0.18
# ===> val loss:		0.20
# ===> val ap:		0.83
# ===> val dice:		0.84
# => saving checkpoint

# %% [markdown]
# ## Predictions

# %%
# %load_ext autoreload
# %autoreload 2
from src.models.dl4mia_tissue_unet import predict
import glob
res_dirs = glob.glob(f"{output_dir}/*")
if res_dirs != []:
  result_dir = res_dirs[-1]
  ckpt_name = "best.pth"
  deploy_dir = "../data/OCT_scans/raw/images"
  predict.main(src_dir=result_dir, ckpt_name=ckpt_name, deploy_dir=None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [INFO] loading up test image paths...
# Loading model...
# Loaded checkpoint: ../src/models/dl4mia_tissue_unet/results\20230424_120831/best.pth
# 	epoch = 28
# 	val_loss = 0.1695588231086731
# 	val_ap = 0.864545464515686
# 	best_dice = 0.8776436448097229
# 	train_cuda = True
# 	model_dict = {'name': 'unet', 'kwargs': {'num_classes': 1, 'depth': 3, 'in_channels': 1, 'batch_norm': True}}
# Load time: 0.31107068061828613
# Created prediction directory: ../src/models/dl4mia_tissue_unet/results\20230424_120831/predictions
# Predict time: 0.058924198150634766
# c:\virenvs\oct_segmentation\unet_segmentation\src\models\dl4mia_tissue_unet\predict.py:185: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figure.show()
# Predict time: 0.10403037071228027
# Predict time: 0.022005319595336914
# Predict time: 0.023911714553833008
# Predict time: 0.02191925048828125
